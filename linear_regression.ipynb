# %% [markdown]
# <a href="https://colab.research.google.com/github/lipika-tp/lipika/blob/main/linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # > Add blockquote

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("regression.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5538/3995280756.py in <cell line: 0>()
# ----> 1 df=pd.read_csv("regression.csv")
#       2 df
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
pd.read_csv("regression.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5538/2386872842.py in <cell line: 0>()
# ----> 1 pd.read_csv("regression.csv")
#
# NameError: name 'pd' is not defined

# %%
df = pd.read_csv("employedetails.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_5538/250646950.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("employedetails.csv.csv")
#       2 df.head()
#
# NameError: name 'pd' is not defined

# %%
df=pd.read_csv("/employedetails.csv")
df
# Out:
#    EmployeeID FirstName   LastName        Department                 Role  \
# 0         101    Julian      Vance  Computer Science            Professor
# 1         102     Elena  Rodriguez       Mathematics  Associate Professor
# 2         103    Marcus       Chen    Administration            Registrar
# 3         104     Sarah    Jenkins           Physics        Lab Assistant
# 4         105    Robert      Smith        Humanities   Head of Department
# 5         106     Aisha       Khan           Library      Chief Librarian
# 6         107     David    Beckham        Admissions            Counselor
# 7         108     Linda   Garrison           Finance           Accountant
#
#                      Email JoiningDate  Salary
# 0      j.vance@college.edu  2018-08-15   95000
# 1  e.rodriguez@college.edu  2019-01-10   82000
# 2       m.chen@college.edu  2015-05-20   75000
# 3    s.jenkins@college.edu  2021-09-01   45000
# 4      r.smith@college.edu  2012-03-12  110000
# ...

# %%
df.head()
# Out:
#    EmployeeID FirstName   LastName        Department                 Role  \
# 0         101    Julian      Vance  Computer Science            Professor
# 1         102     Elena  Rodriguez       Mathematics  Associate Professor
# 2         103    Marcus       Chen    Administration            Registrar
# 3         104     Sarah    Jenkins           Physics        Lab Assistant
# 4         105    Robert      Smith        Humanities   Head of Department
#
#                      Email JoiningDate  Salary
# 0      j.vance@college.edu  2018-08-15   95000
# 1  e.rodriguez@college.edu  2019-01-10   82000
# 2       m.chen@college.edu  2015-05-20   75000
# 3    s.jenkins@college.edu  2021-09-01   45000
# 4      r.smith@college.edu  2012-03-12  110000

# %%
df=pd.read_csv("/housing.csv")
df
# Out:
#    Built-up area  Value
# 0          605.0  167.0
# 1          442.0   83.0
# 2          302.0   53.0
# 3          234.0   57.0
# 4          672.0  152.0
# 5          550.0  120.0
# 6          800.0  195.0
# 7          410.0   90.0

# %% [markdown]
# separating data sets as testing value and training variable

# %%
x=df["Built-up area"]
y=df["Value"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=4)

# %%
x.shape,x_train.shape,x_test.shape
# Out:
# ((8,), (6,), (6,))

# %%
x_train.values
# Out:
# array([234., 605., 442., 550., 800., 302.])

# %%
x_test.values
# Out:
# array([ 57., 167.,  83., 120., 195.,  53.])

# %%
plt.scatter(x_train, x_test)

# %%
plt.scatter(x_train,x_test.values,s=6)
plt.title("houseprice vs floor area")
plt.xlabel("floor area")
plt.ylabel("houseprice")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# to  create object for lg

# %%
lr=LinearRegression()
lr.fit(x_train.values.reshape(-1,1),x_test.values.reshape(-1,1))
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# [-21.19347835]

# %% [markdown]
# intercept and coeffiecnt are imp parameters

# %%
print(lr.coef_)
# Out:
# [[0.27349501]]

# %% [markdown]
# floor area=300 sqft

# %%
lr.predict([[300]])
# Out:
# array([[60.85502524]])

# %% [markdown]
# floor area=500sqft

# %%
lr.predict([[500]])
# Out:
# array([[115.55402763]])

# %%
x_train
# Out:
# 3    234.0
# 0    605.0
# 1    442.0
# 5    550.0
# 6    800.0
# 2    302.0
# Name: Built-up area, dtype: float64

# %%
plt.scatter(x_train,x_test.values,s=6,label="points")
y_pred=lr.predict(x_train.values.reshape(-1,1))
plt.plot(x_train.values,y_pred,label='regression line')
plt.legend()
plt.title("houseprice vs floor area")
plt.xlabel("floor area")
plt.ylabel("houseprice")
plt.show()

# %%
mse=mean_squared_error(y_train,y_pred)
r2=r2_score(y_train,y_pred)
print(mse)
print(r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12724/1798092009.py in <cell line: 0>()
# ----> 1 mse=mean_squared_error(y_train,y_pred)
#       2 r2=r2_score(y_train,y_pred)
#       3 print(mse)
#       4 print(r2)
#
# NameError: name 'mean_squared_error' is not defined
